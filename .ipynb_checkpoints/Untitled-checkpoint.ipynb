# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.8.0.76-cp37-abi3-win_amd64.whl (38.1 MB)
#      ---------------------------------------- 38.1/38.1 MB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in c:\users\admin\anaconda3\lib\site-packages (from opencv-python) (1.23.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.8.0.76

# %%
# !pip install fastai
# Out:
# Collecting fastai
#   Downloading fastai-2.7.12-py3-none-any.whl (233 kB)
#      ------------------------------------ 233.1/233.1 kB 891.3 kB/s eta 0:00:00
# Requirement already satisfied: pip in c:\users\admin\anaconda3\lib\site-packages (from fastai) (22.3.1)
# Collecting fastprogress>=0.2.4
#   Downloading fastprogress-1.0.3-py3-none-any.whl (12 kB)
# Requirement already satisfied: scipy in c:\users\admin\anaconda3\lib\site-packages (from fastai) (1.10.0)
# Collecting spacy<4
#   Downloading spacy-3.6.1-cp310-cp310-win_amd64.whl (12.0 MB)
#      ---------------------------------------- 12.0/12.0 MB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in c:\users\admin\anaconda3\lib\site-packages (from fastai) (3.7.0)
# Requirement already satisfied: torch<2.1,>=1.7 in c:\users\admin\anaconda3\lib\site-packages (from fastai) (1.12.1)
# Requirement already satisfied: requests in c:\users\admin\anaconda3\lib\site-packages (from fastai) (2.28.1)
# Collecting fastcore<1.6,>=1.5.29
#   Downloading fastcore-1.5.29-py3-none-any.whl (67 kB)
#      -------------------------------------- 67.6/67.6 kB 735.3 kB/s eta 0:00:00
# Requirement already satisfied: pillow>6.0.0 in c:\users\admin\anaconda3\lib\site-packages (from fastai) (9.4.0)
# Requirement already satisfied: scikit-learn in c:\users\admin\anaconda3\lib\site-packages (from fastai) (1.2.1)
# Requirement already satisfied: packaging in c:\users\admin\anaconda3\lib\site-packages (from fastai) (22.0)
# Requirement already satisfied: pyyaml in c:\users\admin\anaconda3\lib\site-packages (from fastai) (6.0)
# Collecting torchvision>=0.8.2
#   Downloading torchvision-0.15.2-cp310-cp310-win_amd64.whl (1.2 MB)
#      ---------------------------------------- 1.2/1.2 MB 1.8 MB/s eta 0:00:00
# Collecting fastdownload<2,>=0.0.5
#   Downloading fastdownload-0.0.7-py3-none-any.whl (12 kB)
# Requirement already satisfied: pandas in c:\users\admin\anaconda3\lib\site-packages (from fastai) (1.5.3)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\admin\anaconda3\lib\site-packages (from spacy<4->fastai) (1.23.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\admin\anaconda3\lib\site-packages (from spacy<4->fastai) (4.64.1)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.7-cp310-cp310-win_amd64.whl (481 kB)
#      -------------------------------------- 481.6/481.6 kB 1.7 MB/s eta 0:00:00
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.8-cp310-cp310-win_amd64.whl (94 kB)
#      ---------------------------------------- 94.7/94.7 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in c:\users\admin\anaconda3\lib\site-packages (from spacy<4->fastai) (3.1.2)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4
#   Downloading pydantic-2.3.0-py3-none-any.whl (374 kB)
#      -------------------------------------- 374.5/374.5 kB 1.2 MB/s eta 0:00:00
# Collecting thinc<8.2.0,>=8.1.8
#   Downloading thinc-8.1.12-cp310-cp310-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 2.0 MB/s eta 0:00:00
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.9-py3-none-any.whl (17 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.7-cp310-cp310-win_amd64.whl (29 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.9-cp310-cp310-win_amd64.whl (18 kB)
# Collecting typer<0.10.0,>=0.3.0
#   Downloading typer-0.9.0-py3-none-any.whl (45 kB)
#      ---------------------------------------- 45.9/45.9 kB 2.2 MB/s eta 0:00:00
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      -------------------------------------- 181.6/181.6 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in c:\users\admin\anaconda3\lib\site-packages (from spacy<4->fastai) (65.6.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\admin\anaconda3\lib\site-packages (from spacy<4->fastai) (5.2.1)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.4-py3-none-any.whl (11 kB)
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Collecting pathy>=0.10.0
#   Downloading pathy-0.10.2-py3-none-any.whl (48 kB)
#      -------------------------------------- 48.9/48.9 kB 623.0 kB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests->fastai) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests->fastai) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests->fastai) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests->fastai) (3.4)
# Requirement already satisfied: typing_extensions in c:\users\admin\anaconda3\lib\site-packages (from torch<2.1,>=1.7->fastai) (4.4.0)
# Collecting torch<2.1,>=1.7
#   Downloading torch-2.0.1-cp310-cp310-win_amd64.whl (172.3 MB)
#      ------------------------------------ 172.3/172.3 MB 872.1 kB/s eta 0:00:00
# Requirement already satisfied: sympy in c:\users\admin\anaconda3\lib\site-packages (from torch<2.1,>=1.7->fastai) (1.11.1)
# Requirement already satisfied: networkx in c:\users\admin\anaconda3\lib\site-packages (from torch<2.1,>=1.7->fastai) (2.8.4)
# Requirement already satisfied: filelock in c:\users\admin\anaconda3\lib\site-packages (from torch<2.1,>=1.7->fastai) (3.9.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib->fastai) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib->fastai) (1.0.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib->fastai) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib->fastai) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib->fastai) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib->fastai) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas->fastai) (2022.7)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn->fastai) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn->fastai) (2.2.0)
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.5.0-py3-none-any.whl (11 kB)
# Collecting pydantic-core==2.6.3
#   Downloading pydantic_core-2.6.3-cp310-none-win_amd64.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 1.3 MB/s eta 0:00:00
# Collecting typing_extensions
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->fastai) (1.16.0)
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.1.1-py3-none-any.whl (34 kB)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.10-cp310-cp310-win_amd64.whl (7.4 MB)
#      ---------------------------------------- 7.4/7.4 MB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<4->fastai) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\admin\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<4->fastai) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\anaconda3\lib\site-packages (from jinja2->spacy<4->fastai) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\admin\anaconda3\lib\site-packages (from sympy->torch<2.1,>=1.7->fastai) (1.2.1)
# Installing collected packages: cymem, wasabi, typing_extensions, spacy-loggers, spacy-legacy, murmurhash, langcodes, fastprogress, fastcore, catalogue, blis, annotated-types, typer, torch, srsly, pydantic-core, preshed, fastdownload, torchvision, pydantic, pathy, confection, thinc, spacy, fastai
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.4.0
#     Uninstalling typing_extensions-4.4.0:
#       Successfully uninstalled typing_extensions-4.4.0
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1
#     Uninstalling torch-1.12.1:
#       Successfully uninstalled torch-1.12.1
# Successfully installed annotated-types-0.5.0 blis-0.7.10 catalogue-2.0.9 confection-0.1.1 cymem-2.0.7 fastai-2.7.12 fastcore-1.5.29 fastdownload-0.0.7 fastprogress-1.0.3 langcodes-3.3.0 murmurhash-1.0.9 pathy-0.10.2 preshed-3.0.8 pydantic-2.3.0 pydantic-core-2.6.3 spacy-3.6.1 spacy-legacy-3.0.12 spacy-loggers-1.0.4 srsly-2.4.7 thinc-8.1.12 torch-2.0.1 torchvision-0.15.2 typer-0.9.0 typing_extensions-4.7.1 wasabi-1.1.2

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Flatten,Dropout,Conv2D,MaxPooling2D,BatchNormalization

# %%
imre = plt.imread(r"C:\Users\ADMIN\Downloads\CDS MY TEAM PROJECT\TEAM\RICE LEAF\Bacterial leaf blight\DSC_0376.JPG")
img = plt.imshow(imre)
